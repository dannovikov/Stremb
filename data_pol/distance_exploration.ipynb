# %%
import pandas as pd
dists = 'dists.csv'
dists = pd.read_csv(dists, index_col=0)

# %%
dists
# Out:
#                         Target  Distance
# Source
# 01_AE.AB032740      C.AB023804  0.118238
# 01_AE.AB032741      C.AB023804  0.115517
# 01_AE.AB032741  01_AE.AB032740  0.023355
# 02_AG.AB049811      C.AB023804  0.114556
# 02_AG.AB049811  01_AE.AB032741  0.099102
# ...                        ...       ...
# G.U88826              B.U71182  0.119674
# G.U88826          01_AE.U54771  0.110889
# G.U88826              B.U69584  0.107135
# G.U88826              D.U88822  0.109640
# G.U88826              D.U88824  0.114998
#
# [18033015 rows x 2 columns]

# %%
#sort by distance column
dists = dists.sort_values(by=['Distance'])

# %%
dists[dists.Distance != 0]
# Out:
#                      Target  Distance
# Source
# C.KX228821       C.EU786681  0.000352
# B.KX228802       B.KC473826  0.000352
# C.KM050035       C.KC018987  0.000352
# C.KM050714       C.KC018729  0.000352
# C.KM049913       C.KC018485  0.000352
# ...                     ...       ...
# C.KP411837       B.EF178319  0.170151
# C.KP411837   01_AE.KF835514  0.171079
# C.KP411837  39_BF1.EU735534  0.171204
# C.KP411837  37_cpx.EF116594  0.171338
# C.KP411837   01_AE.JQ028212  0.173637
#
# [18032967 rows x 2 columns]
